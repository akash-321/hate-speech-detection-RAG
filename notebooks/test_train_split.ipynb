# %%
pip install datasets pandas numpy matplotlib seaborn krippendorff
# Out:
# Requirement already satisfied: datasets in /opt/anaconda3/lib/python3.13/site-packages (4.5.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (3.0.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (2.1.3)
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.13/site-packages (3.10.0)
# Requirement already satisfied: seaborn in /opt/anaconda3/lib/python3.13/site-packages (0.13.2)
# Requirement already satisfied: krippendorff in /opt/anaconda3/lib/python3.13/site-packages (0.8.2)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (3.17.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (23.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: requests>=2.32.2 in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.3.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.13/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/lib/python3.13/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.11.10)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (4.7.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.18.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.13/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import krippendorff
from datasets import load_dataset
import pandas as pd
import numpy as np

from pandas.core.computation.check import NUMEXPR_INSTALLED
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
dataset = load_dataset("ucberkeley-dlab/measuring-hate-speech")

# %%
dataset["train"][0]
# Out:
# {'comment_id': 47777,
#  'annotator_id': 10873,
#  'platform': 3,
#  'sentiment': 0.0,
#  'respect': 0.0,
#  'insult': 0.0,
#  'humiliate': 0.0,
#  'status': 2.0,
#  'dehumanize': 0.0,
#  'violence': 0.0,
#  'genocide': 0.0,
#  'attack_defend': 0.0,
#  'hatespeech': 0.0,
#  'hate_speech_score': -3.9,
#  'text': 'Yes indeed. She sort of reminds me of the elder lady that played the part in the movie "Titanic" who was telling her story!!! And I wouldn\'t have wanted to cover who I really am!! I would be proud!!!! WE should be proud of our race no matter what it is!!',
#  'infitms': 0.81,
#  'outfitms': 1.88,
#  'annotator_severity': 0.36,
#  'std_err': 0.34,
#  'annotator_infitms': 1.35,
#  'annotator_outfitms': 1.23,
#  'hypothesis': -1.1301777576839678,
#  'target_race_asian': True,
#  'target_race_black': True,
#  'target_race_latinx': True,
#  'target_race_middle_eastern': True,
#  'target_race_native_american': True,
#  'target_race_pacific_islander': True,
#  'target_race_white': True,
#  'target_race_other': False,
#  'target_race': True,
#  'target_religion_atheist': False,
#  'target_religion_buddhist': False,
#  'target_religion_christian': False,
#  'target_religion_hindu': False,
#  'target_religion_jewish': False,
#  'target_religion_mormon': False,
#  'target_religion_muslim': False,
#  'target_religion_other': False,
#  'target_religion': False,
#  'target_origin_immigrant': False,
#  'target_origin_migrant_worker': False,
#  'target_origin_specific_country': False,
#  'target_origin_undocumented': False,
#  'target_origin_other': False,
#  'target_origin': False,
#  'target_gender_men': False,
#  'target_gender_non_binary': False,
#  'target_gender_transgender_men': False,
#  'target_gender_transgender_unspecified': False,
#  'target_gender_transgender_women': False,
#  'target_gender_women': False,
#  'target_gender_other': False,
#  'target_gender': False,
#  'target_sexuality_bisexual': False,
#  'target_sexuality_gay': False,
#  'target_sexuality_lesbian': False,
#  'target_sexuality_straight': False,
#  'target_sexuality_other': False,
#  'target_sexuality': False,
#  'target_age_children': False,
#  'target_age_teenagers': False,
#  'target_age_young_adults': False,
#  'target_age_middle_aged': False,
#  'target_age_seniors': False,
#  'target_age_other': False,
#  'target_age': False,
#  'target_disability_physical': False,
#  'target_disability_cognitive': False,
#  'target_disability_neurological': False,
#  'target_disability_visually_impaired': False,
#  'target_disability_hearing_impaired': False,
#  'target_disability_unspecific': False,
#  'target_disability_other': False,
#  'target_disability': False,
#  'target_politics_alt_right': False,
#  'target_politics_communist': False,
#  'target_politics_conservative': False,
#  'target_politics_democrat': False,
#  'target_politics_green_party': False,
#  'target_politics_leftist': False,
#  'target_politics_liberal': False,
#  'target_politics_libertarian': False,
#  'target_politics_republican': False,
#  'target_politics_socialist': False,
#  'target_politics_other': False,
#  'target_politics': False,
#  'annotator_gender': 'male',
#  'annotator_trans': 'no',
#  'annotator_educ': 'college_grad_ba',
#  'annotator_income': '<10k',
#  'annotator_ideology': 'neutral',
#  'annotator_gender_men': True,
#  'annotator_gender_women': False,
#  'annotator_gender_non_binary': False,
#  'annotator_gender_prefer_not_to_say': False,
#  'annotator_gender_self_describe': False,
#  'annotator_transgender': False,
#  'annotator_cisgender': True,
#  'annotator_transgender_prefer_not_to_say': False,
#  'annotator_education_some_high_school': False,
#  'annotator_education_high_school_grad': False,
#  'annotator_education_some_college': False,
#  'annotator_education_college_grad_aa': False,
#  'annotator_education_college_grad_ba': True,
#  'annotator_education_professional_degree': False,
#  'annotator_education_masters': False,
#  'annotator_education_phd': False,
#  'annotator_income_<10k': True,
#  'annotator_income_10k-50k': False,
#  'annotator_income_50k-100k': False,
#  'annotator_income_100k-200k': False,
#  'annotator_income_>200k': False,
#  'annotator_ideology_extremeley_conservative': False,
#  'annotator_ideology_conservative': False,
#  'annotator_ideology_slightly_conservative': False,
#  'annotator_ideology_neutral': True,
#  'annotator_ideology_slightly_liberal': False,
#  'annotator_ideology_liberal': False,
#  'annotator_ideology_extremeley_liberal': False,
#  'annotator_ideology_no_opinion': False,
#  'annotator_race_asian': False,
#  'annotator_race_black': False,
#  'annotator_race_latinx': False,
#  'annotator_race_middle_eastern': False,
#  'annotator_race_native_american': False,
#  'annotator_race_pacific_islander': False,
#  'annotator_race_white': True,
#  'annotator_race_other': False,
#  'annotator_age': 25.0,
#  'annotator_religion_atheist': False,
#  'annotator_religion_buddhist': False,
#  'annotator_religion_christian': True,
#  'annotator_religion_hindu': False,
#  'annotator_religion_jewish': False,
#  'annotator_religion_mormon': False,
#  'annotator_religion_muslim': False,
#  'annotator_religion_nothing': False,
#  'annotator_religion_other': False,
#  'annotator_sexuality_bisexual': False,
#  'annotator_sexuality_gay': False,
#  'annotator_sexuality_straight': True,
#  'annotator_sexuality_other': False}

# %%
df = pd.DataFrame(dataset["train"])

# %% [markdown]
#  # Checking for duplicates

# %% [markdown]
# #### Checking exact duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Checking duplicates ignoring the index (same content, repeated)

# %%
df.reset_index(drop=True).duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Checking duplicates on comment id and annotator id

# %%
df.duplicated(subset=["comment_id", "annotator_id"]).sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Checking duplicates on text and annotator id

# %%
df.duplicated(subset=["text", "annotator_id"]).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Splitting (70% Training, 20% Testing, 10%Validation)

# %%
from sklearn.model_selection import train_test_split

comment_ids = df["comment_id"].unique()

# %%
comment_ids
# Out:
# array([47777, 39773, 47101, ..., 30588, 21008, 37080])

# %%
train_ids, temp_ids = train_test_split(
    comment_ids,
    test_size=0.30,
    random_state=42
)

test_ids, val_ids = train_test_split(
    temp_ids,
    test_size=1/3,
    random_state=42
)

# %%
train_df = df[df["comment_id"].isin(train_ids)]
test_df  = df[df["comment_id"].isin(test_ids)]
val_df   = df[df["comment_id"].isin(val_ids)]

# %%
print("Original rows:", len(df))
print("Train rows:", len(train_df))
print("Test rows:", len(test_df))
print("Validation rows:", len(val_df))
print("Total after split:", len(train_df) + len(test_df) + len(val_df))
# Out:
# Original rows: 135556
# Train rows: 93935
# Test rows: 25413
# Validation rows: 16208
# Total after split: 135556

# %%
total_rows = len(df)

print("Train %:", round(len(train_df) / total_rows * 100, 2))
print("Test %:", round(len(test_df) / total_rows * 100, 2))
print("Validation %:", round(len(val_df) / total_rows * 100, 2))
# Out:
# Train %: 69.3
# Test %: 18.75
# Validation %: 11.96

# %% [markdown]
# *Note - Splitting is done based on the comments. After splitting, annotators are added for that comment and hence the variation in dataset splitting percentage (which is almost around 70-20-10).*

# %% [markdown]
# ## Checking Data Leakage

# %% [markdown]
# #### Checking comment-level leakage

# %%
train_ids = set(train_df["comment_id"])
test_ids  = set(test_df["comment_id"])
val_ids   = set(val_df["comment_id"])

print("Train and Test:", len(train_ids & test_ids))
print("Train and Val:", len(train_ids & val_ids))
print("Test and Val:", len(test_ids & val_ids))
# Out:
# Train and Test: 0
# Train and Val: 0
# Test and Val: 0

# %% [markdown]
# #### Checking annotation-level leakage

# %%
train_pairs = set(zip(train_df["comment_id"], train_df["annotator_id"]))
test_pairs  = set(zip(test_df["comment_id"], test_df["annotator_id"]))
val_pairs   = set(zip(val_df["comment_id"], val_df["annotator_id"]))

print("Train and Test (pairs):", len(train_pairs & test_pairs))
print("Train and Val (pairs):", len(train_pairs & val_pairs))
print("Test and Val (pairs):", len(test_pairs & val_pairs))
# Out:
# Train and Test (pairs): 0
# Train and Val (pairs): 0
# Test and Val (pairs): 0

# %% [markdown]
# #### Checking no rows were lost

# %%
print("Original rows:", len(df))
print("After split:", len(train_df) + len(test_df) + len(val_df))
# Out:
# Original rows: 135556
# After split: 135556

# %% [markdown]
# # New Splitting Criteria

# %%
annotator_religions = [
    "annotator_religion_muslim",
    "annotator_religion_christian",
    "annotator_religion_jewish",
    "annotator_religion_atheist",
    "annotator_religion_buddhist"
]

target_religions = [
    "target_religion_muslim",
    "target_religion_christian",
    "target_religion_jewish",
    "target_religion_atheist",
    "target_religion_buddhist"
]

df["hate_speech_score"] = pd.to_numeric(df["hate_speech_score"], errors="coerce")
df["is_hate_speech"] = df["hate_speech_score"] > 0.5

# %%
def make_hate_nonhate_table(dataframe):
    table = pd.DataFrame()

    for a_col in annotator_religions:
        row_name = a_col.replace("annotator_religion_", "").capitalize() + " annotators"
        row_data = {}

        annotator_subset = dataframe[dataframe[a_col] == 1]

        for t_col in target_religions:
            target_name = t_col.replace("target_religion_", "").capitalize()
            subset = annotator_subset[annotator_subset[t_col] == 1]

            total = len(subset)

            if total > 0:
                hate_pct = round(subset["is_hate_speech"].mean() * 100, 2)
                non_hate_pct = round(100 - hate_pct, 2)
            else:
                hate_pct = np.nan
                non_hate_pct = np.nan

            row_data[f"% Hate → {target_name}"] = hate_pct
            row_data[f"% Non-Hate → {target_name}"] = non_hate_pct

        table = pd.concat([table, pd.DataFrame(row_data, index=[row_name])])

    return table

# %%
print("BEFORE SPLITTING (FULL DATASET)")
print("Total rows:", len(df))
print("Unique comments:", df["comment_id"].nunique())

overall_hate = round(df["is_hate_speech"].mean() * 100, 2)
print("Overall Hate %:", overall_hate)
print("Overall Non-Hate %:", round(100 - overall_hate, 2))

full_table = make_hate_nonhate_table(df)
full_table
# Out:
# BEFORE SPLITTING (FULL DATASET)
# Total rows: 135556
# Unique comments: 39565
# Overall Hate %: 36.18
# Overall Non-Hate %: 63.82
#                       % Hate → Muslim  % Non-Hate → Muslim  \
# Muslim annotators               33.02                66.98
# Christian annotators            40.79                59.21
# Jewish annotators               45.45                54.55
# Atheist annotators              43.23                56.77
# Buddhist annotators             39.15                60.85
#
#                       % Hate → Christian  % Non-Hate → Christian  \
# Muslim annotators                  12.73                   87.27
# Christian annotators               13.29                   86.71
# Jewish annotators                  13.13                   86.87
# Atheist annotators                 10.27                   89.73
# Buddhist annotators                12.95                   87.05
#
#                       % Hate → Jewish  % Non-Hate → Jewish  % Hate → Atheist  \
# Muslim annotators               61.54                38.46             26.67
# Christian annotators            63.01                36.99             18.93
# Jewish annotators               69.13                30.87             35.71
# Atheist annotators              66.23                33.77             18.54
# Buddhist annotators             62.00                38.00              5.88
#
#                       % Non-Hate → Atheist  % Hate → Buddhist  \
# Muslim annotators                    73.33              25.00
# Christian annotators                 81.07              23.80
# Jewish annotators                    64.29              33.33
# Atheist annotators                   81.46              20.00
# Buddhist annotators                  94.12              25.00
#
#                       % Non-Hate → Buddhist
# Muslim annotators                     75.00
# Christian annotators                  76.20
# Jewish annotators                     66.67
# Atheist annotators                    80.00
# Buddhist annotators                   75.00

# %%
comment_level = (
    df.groupby("comment_id")
      .agg(mean_score=("hate_speech_score", "mean"))
      .reset_index()
)

comment_level["label"] = (comment_level["mean_score"] > 0.5).astype(int)

comment_ids = comment_level["comment_id"]
comment_labels = comment_level["label"]

train_ids, temp_ids = train_test_split(
    comment_ids,
    test_size=0.30,
    random_state=42,
    stratify=comment_labels
)

temp_df = comment_level[comment_level["comment_id"].isin(temp_ids)]

test_ids, val_ids = train_test_split(
    temp_df["comment_id"],
    test_size=1/3,               # val = 10%, test = 20%
    random_state=42,
    stratify=temp_df["label"]
)
train_df = df[df["comment_id"].isin(train_ids)]
test_df  = df[df["comment_id"].isin(test_ids)]
val_df   = df[df["comment_id"].isin(val_ids)]

# %%
print("\nAFTER SPLITTING ")
print("Original rows:", len(df))
print("Train rows:", len(train_df))
print("Test rows:", len(test_df))
print("Val rows:", len(val_df))
print("Total after split:", len(train_df) + len(test_df) + len(val_df))

print("\nRow %:")
print("Train %:", round(len(train_df)/len(df)*100, 2))
print("Test %:", round(len(test_df)/len(df)*100, 2))
print("Val %:", round(len(val_df)/len(df)*100, 2))

print("\nComment %:")
print("Train comment %:", round(train_df["comment_id"].nunique()/df["comment_id"].nunique()*100, 2))
print("Test comment %:", round(test_df["comment_id"].nunique()/df["comment_id"].nunique()*100, 2))
print("Val comment %:", round(val_df["comment_id"].nunique()/df["comment_id"].nunique()*100, 2))

print("\nOverall Hate/Non-Hate % by split:")
for name, d in [("Train", train_df), ("Test", test_df), ("Val", val_df)]:
    hate = round(d["is_hate_speech"].mean()*100, 2)
    print(name, "Hate %:", hate, "| Non-Hate %:", round(100-hate, 2))
# Out:
# AFTER SPLITTING
# Original rows: 135556
# Train rows: 94851
# Test rows: 26632
# Val rows: 14073
# Total after split: 135556
#
# Row %:
# Train %: 69.97
# Test %: 19.65
# Val %: 10.38
#
# Comment %:
# Train comment %: 70.0
# Test comment %: 20.0
# Val comment %: 10.0
#
# Overall Hate/Non-Hate % by split:
# Train Hate %: 37.13 | Non-Hate %: 62.87
# Test Hate %: 32.59 | Non-Hate %: 67.41
# Val Hate %: 36.59 | Non-Hate %: 63.41

# %%
print("\n TRAIN TABLE ")
train_table = make_hate_nonhate_table(train_df)
train_table
# Out:
#  TRAIN TABLE
#                       % Hate → Muslim  % Non-Hate → Muslim  \
# Muslim annotators               41.33                58.67
# Christian annotators            48.27                51.73
# Jewish annotators               56.35                43.65
# Atheist annotators              50.31                49.69
# Buddhist annotators             44.30                55.70
#
#                       % Hate → Christian  % Non-Hate → Christian  \
# Muslim annotators                  15.79                   84.21
# Christian annotators               17.45                   82.55
# Jewish annotators                  13.21                   86.79
# Atheist annotators                 12.05                   87.95
# Buddhist annotators                12.99                   87.01
#
#                       % Hate → Jewish  % Non-Hate → Jewish  % Hate → Atheist  \
# Muslim annotators               54.84                45.16             27.27
# Christian annotators            60.78                39.22             21.59
# Jewish annotators               65.22                34.78             40.00
# Atheist annotators              62.40                37.60             17.80
# Buddhist annotators             59.02                40.98              7.69
#
#                       % Non-Hate → Atheist  % Hate → Buddhist  \
# Muslim annotators                    72.73              28.57
# Christian annotators                 78.41              27.16
# Jewish annotators                    60.00              25.00
# Atheist annotators                   82.20              16.67
# Buddhist annotators                  92.31              30.77
#
#                       % Non-Hate → Buddhist
# Muslim annotators                     71.43
# Christian annotators                  72.84
# Jewish annotators                     75.00
# Atheist annotators                    83.33
# Buddhist annotators                   69.23

# %%
print("\nTEST TABLE ")
test_table = make_hate_nonhate_table(test_df)
test_table
# Out:
# TEST TABLE
#                       % Hate → Muslim  % Non-Hate → Muslim  \
# Muslim annotators               11.11                88.89
# Christian annotators            15.15                84.85
# Jewish annotators               11.63                88.37
# Atheist annotators              16.67                83.33
# Buddhist annotators             11.43                88.57
#
#                       % Hate → Christian  % Non-Hate → Christian  \
# Muslim annotators                   8.33                   91.67
# Christian annotators                9.38                   90.62
# Jewish annotators                  17.24                   82.76
# Atheist annotators                  8.96                   91.04
# Buddhist annotators                18.18                   81.82
#
#                       % Hate → Jewish  % Non-Hate → Jewish  % Hate → Atheist  \
# Muslim annotators               78.95                21.05             33.33
# Christian annotators            70.91                29.09             14.94
# Jewish annotators               72.92                27.08             50.00
# Atheist annotators              75.17                24.83             14.71
# Buddhist annotators             74.19                25.81              0.00
#
#                       % Non-Hate → Atheist  % Hate → Buddhist  \
# Muslim annotators                    66.67              20.00
# Christian annotators                 85.06              15.52
# Jewish annotators                    50.00              33.33
# Atheist annotators                   85.29              24.14
# Buddhist annotators                 100.00               0.00
#
#                       % Non-Hate → Buddhist
# Muslim annotators                     80.00
# Christian annotators                  84.48
# Jewish annotators                     66.67
# Atheist annotators                    75.86
# Buddhist annotators                  100.00

# %%
print("\nVALIDATION TABLE")
val_table = make_hate_nonhate_table(val_df)
val_table
# Out:
# VALIDATION TABLE
#                       % Hate → Muslim  % Non-Hate → Muslim  \
# Muslim annotators               15.38                84.62
# Christian annotators            41.23                58.77
# Jewish annotators               47.50                52.50
# Atheist annotators              43.23                56.77
# Buddhist annotators             46.43                53.57
#
#                       % Hate → Christian  % Non-Hate → Christian  \
# Muslim annotators                   0.00                  100.00
# Christian annotators                6.32                   93.68
# Jewish annotators                   5.88                   94.12
# Atheist annotators                  7.30                   92.70
# Buddhist annotators                 6.90                   93.10
#
#                       % Hate → Jewish  % Non-Hate → Jewish  % Hate → Atheist  \
# Muslim annotators                0.00               100.00              0.00
# Christian annotators            51.07                48.93              8.51
# Jewish annotators               88.89                11.11              0.00
# Atheist annotators              59.57                40.43             26.92
# Buddhist annotators             37.50                62.50              0.00
#
#                       % Non-Hate → Atheist  % Hate → Buddhist  \
# Muslim annotators                   100.00                NaN
# Christian annotators                 91.49              12.90
# Jewish annotators                   100.00             100.00
# Atheist annotators                   73.08              36.36
# Buddhist annotators                 100.00               0.00
#
#                       % Non-Hate → Buddhist
# Muslim annotators                       NaN
# Christian annotators                  87.10
# Jewish annotators                      0.00
# Atheist annotators                    63.64
# Buddhist annotators                  100.00

# %% [markdown]
# # Correct Splitting

# %%
annotator_religions = ["muslim", "christian", "jewish", "atheist", "buddhist"]
target_religions    = ["muslim", "christian", "jewish", "atheist", "buddhist"]

annotator_cols = [f"annotator_religion_{r}" for r in annotator_religions]
target_cols    = [f"target_religion_{r}" for r in target_religions]

df["hate_speech_score"] = pd.to_numeric(df["hate_speech_score"], errors="coerce")
df["is_hate_speech"] = (df["hate_speech_score"] > 0.5).astype(int)

df5 = df.copy()

df5["annotator_group"] = np.select(
    [df5[c].astype(int) == 1 for c in annotator_cols],
    annotator_religions,
    default=None
)

df5["target_group"] = np.select(
    [df5[c].astype(int) == 1 for c in target_cols],
    target_religions,
    default=None
)

df5 = df5.dropna(subset=["annotator_group", "target_group"])

print("Filtered rows:", len(df5))
print("Unique comments:", df5["comment_id"].nunique())
# Out:
# Filtered rows: 15856
# Unique comments: 5428

# %%
print("Rows after filtering to 5×5 religions:", len(df5))
print("Annotator groups:", df5["annotator_group"].value_counts())
print("Target groups:", df5["target_group"].value_counts())
# Out:
# Rows after filtering to 5×5 religions: 15856
# Annotator groups: annotator_group
# christian    10050
# atheist       4864
# jewish         407
# buddhist       348
# muslim         187
# Name: count, dtype: int64
# Target groups: target_group
# muslim       8309
# christian    3648
# jewish       3584
# atheist       278
# buddhist       37
# Name: count, dtype: int64

# %%
df5["strat_bin"] = (
    df5["annotator_group"] + "|" +
    df5["target_group"] + "|" +
    df5["is_hate_speech"].astype(str)
)

# %%
comment_bin_counts = (
    df5.groupby(["comment_id", "strat_bin"])
        .size()
        .reset_index(name="count")
)

# %%
comment_bin_counts = comment_bin_counts.sort_values(
    ["comment_id", "count"],
    ascending=[True, False]
)

comment_bins = comment_bin_counts.drop_duplicates("comment_id")

comment_bins = comment_bins[["comment_id", "strat_bin"]]

# %%
bin_counts = comment_bins["strat_bin"].value_counts()

MIN_BIN_SIZE = 2

comment_bins["strat_bin_fixed"] = comment_bins["strat_bin"].where(
    comment_bins["strat_bin"].map(bin_counts) >= MIN_BIN_SIZE,
    "OTHER_BIN"
)

print("Number of original bins:", comment_bins["strat_bin"].nunique())
print("Number of fixed bins:", comment_bins["strat_bin_fixed"].nunique())
print("Rare bins collapsed into OTHER_BIN:",
      (comment_bins["strat_bin_fixed"] == "OTHER_BIN").sum())
# Out:
# Number of original bins: 44
# Number of fixed bins: 38
# Rare bins collapsed into OTHER_BIN: 7

# %%
RANDOM_SEED = 42
rng = np.random.default_rng(RANDOM_SEED)

train_ids = []
test_ids = []
val_ids = []

for bin_name, group in comment_bins.groupby("strat_bin_fixed"):
    ids = group["comment_id"].to_numpy().copy()
    rng.shuffle(ids)

    n = len(ids)
    n_train = int(round(n * 0.70))
    n_test  = int(round(n * 0.20))
    n_val   = n - n_train - n_test  # remainder goes to val (≈10%)

    train_ids.extend(ids[:n_train])
    test_ids.extend(ids[n_train:n_train+n_test])
    val_ids.extend(ids[n_train+n_test:])

train_ids = np.array(train_ids)
test_ids  = np.array(test_ids)
val_ids   = np.array(val_ids)

print("Train comments:", len(train_ids))
print("Test comments:", len(test_ids))
print("Val comments:", len(val_ids))

train_df = df5[df5["comment_id"].isin(train_ids)]
test_df  = df5[df5["comment_id"].isin(test_ids)]
val_df   = df5[df5["comment_id"].isin(val_ids)]

print("Train rows:", len(train_df))
print("Test rows:", len(test_df))
print("Val rows:", len(val_df))
print("Total rows after split:", len(train_df)+len(test_df)+len(val_df))
print("Original rows:", len(df5))
# Out:
# Train comments: 3795
# Test comments: 1084
# Val comments: 549
# Train rows: 9581
# Test rows: 3782
# Val rows: 2493
# Total rows after split: 15856
# Original rows: 15856

# %%
print("Train∩Test:", len(set(train_ids) & set(test_ids)))
print("Train∩Val:", len(set(train_ids) & set(val_ids)))
print("Test∩Val:", len(set(test_ids) & set(val_ids)))
# Out:
# Train∩Test: 0
# Train∩Val: 0
# Test∩Val: 0

# %%
def make_table(data):
    table = pd.DataFrame()

    for a in annotator_religions:
        row = {}
        sub_a = data[data["annotator_group"] == a]

        for t in target_religions:
            sub = sub_a[sub_a["target_group"] == t]
            total = len(sub)

            if total > 0:
                hate = round(sub["is_hate_speech"].mean() * 100, 2)
                non = round(100 - hate, 2)
            else:
                hate = np.nan
                non = np.nan

            row[f"% Hate - {t.capitalize()}"] = hate
            row[f"% Non-Hate - {t.capitalize()}"] = non

        table = pd.concat([table, pd.DataFrame(row, index=[a.capitalize()+" annotators"])])

    return table

# %%
def make_table_b(df, title):
    s = df.style.format("{:.2f}").set_caption(title)
    hate_cols = [c for c in df.columns if "Hate -" in c]
    non_cols  = [c for c in df.columns if "Non-Hate -" in c]

    s = s.set_properties(subset=hate_cols, **{"font-weight": "bold"})
    s = s.set_properties(subset=non_cols, **{"color": "gray"})
    s = s.background_gradient(axis=None)
    return s

display(make_table_b(full_table, "Full Dataset: Hate vs Non-Hate (%)"))
display(make_table_b(train_table, "Train (70%)"))
display(make_table_b(test_table, "Test (20%)"))
display(make_table_b(val_table, "Validation (10%)"))
# Out:
# <style type="text/css">
# #T_63871_row0_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_63871_row0_col1 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_63871_row0_col2 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_63871_row0_col3 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_63871_row0_col4 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_63871_row0_col5 {
#   background-color: #a8bedc;
#   color: #000000;
# }
# #T_63871_row0_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_63871_row0_col7 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_63871_row0_col8, #T_63871_row4_col8 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_63871_row0_col9, #T_63871_row4_col9 {
#   background-color: #056aa6;
#   color: #f1f1f1;
# }
# #T_63871_row1_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_63871_row1_col1 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_63871_row1_col2, #T_63871_row2_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_63871_row1_col3, #T_63871_row2_col3 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_63871_row1_col4 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_63871_row1_col5 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_63871_row1_col6 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_63871_row1_col7 {
#   background-color: #045e93;
#   color: #f1f1f1;
# }
# #T_63871_row1_col8 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_63871_row1_col9 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_63871_row2_col0 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_63871_row2_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_63871_row2_col4 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_63871_row2_col5 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_63871_row2_col6 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_63871_row2_col7 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# #T_63871_row2_col8 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_63871_row2_col9 {
#   background-color: #1c7fb8;
#   color: #f1f1f1;
# }
# #T_63871_row3_col0 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_63871_row3_col1 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_63871_row3_col2 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_63871_row3_col3 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_63871_row3_col4 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_63871_row3_col5 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_63871_row3_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_63871_row3_col7 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_63871_row3_col8 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_63871_row3_col9 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_63871_row4_col0 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_63871_row4_col1 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_63871_row4_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_63871_row4_col3 {
#   background-color: #034d79;
#   color: #f1f1f1;
# }
# #T_63871_row4_col4 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_63871_row4_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_63871_row4_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_63871_row4_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_63871">
#   <caption>Full Dataset: Hate vs Non-Hate (%)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63871_level0_col0" class="col_heading level0 col0" >% Hate → Muslim</th>
#       <th id="T_63871_level0_col1" class="col_heading level0 col1" >% Non-Hate → Muslim</th>
#       <th id="T_63871_level0_col2" class="col_heading level0 col2" >% Hate → Christian</th>
#       <th id="T_63871_level0_col3" class="col_heading level0 col3" >% Non-Hate → Christian</th>
#       <th id="T_63871_level0_col4" class="col_heading level0 col4" >% Hate → Jewish</th>
#       <th id="T_63871_level0_col5" class="col_heading level0 col5" >% Non-Hate → Jewish</th>
#       <th id="T_63871_level0_col6" class="col_heading level0 col6" >% Hate → Atheist</th>
#       <th id="T_63871_level0_col7" class="col_heading level0 col7" >% Non-Hate → Atheist</th>
#       <th id="T_63871_level0_col8" class="col_heading level0 col8" >% Hate → Buddhist</th>
#       <th id="T_63871_level0_col9" class="col_heading level0 col9" >% Non-Hate → Buddhist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_
#       <td id="T_63871_row3_col7" class="data row3 col7" >81.46</td>
#       <td id="T_63871_row3_col8" class="data row3 col8" >20.00</td>
#       <td id="T_63871_row3_col9" class="data row3 col9" >80.00</td>
#     </tr>
#     <tr>
#       <th id="T_63871_level0_row4" class="row_heading level0 row4" >Buddhist annotators</th>
#       <td id="T_63871_row4_col0" class="data row4 col0" >39.15</td>
#       <td id="T_63871_row4_col1" class="data row4 col1" >60.85</td>
#       <td id="T_63871_row4_col2" class="data row4 col2" >12.95</td>
#       <td id="T_63871_row4_col3" class="data row4 col3" >87.05</td>
#       <td id="T_63871_row4_col4" cla
# <style type="text/css">
# #T_9c998_row0_col0 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_9c998_row0_col1 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_9c998_row0_col2 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_9c998_row0_col3 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_9c998_row0_col4 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_9c998_row0_col5 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_9c998_row0_col6 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_9c998_row0_col7 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_9c998_row0_col8 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_9c998_row0_col9 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_9c998_row1_col0 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_9c998_row1_col1 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_9c998_row1_col2 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_9c998_row1_col3 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_9c998_row1_col4 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_9c998_row1_col5 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_9c998_row1_col6 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_9c998_row1_col7 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_9c998_row1_col8 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_9c998_row1_col9 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_9c998_row2_col0 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_9c998_row2_col1 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_9c998_row2_col2, #T_9c998_row4_col2 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_9c998_row2_col3, #T_9c998_row4_col3 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_9c998_row2_col4 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_9c998_row2_col5 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_9c998_row2_col6 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_9c998_row2_col7 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_9c998_row2_col8 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_9c998_row2_col9 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_9c998_row3_col0 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_9c998_row3_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_9c998_row3_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_9c998_row3_col3 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_9c998_row3_col4 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_9c998_row3_col5 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_9c998_row3_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_9c998_row3_col7 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_9c998_row3_col8 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_9c998_row3_col9 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_9c998_row4_col0 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_9c998_row4_col1 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_9c998_row4_col4 {
#   background-color: #3f93c2;
#   color: #f1f1f1;
# }
# #T_9c998_row4_col5 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_9c998_row4_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9c998_row4_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9c998_row4_col8 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_9c998_row4_col9 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c998">
#   <caption>Train (70%)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c998_level0_col0" class="col_heading level0 col0" >% Hate → Muslim</th>
#       <th id="T_9c998_level0_col1" class="col_heading level0 col1" >% Non-Hate → Muslim</th>
#       <th id="T_9c998_level0_col2" class="col_heading level0 col2" >% Hate → Christian</th>
#       <th id="T_9c998_level0_col3" class="col_heading level0 col3" >% Non-Hate → Christian</th>
#       <th id="T_9c998_level0_col4" class="col_heading level0 col4" >% Hate → Jewish</th>
#       <th id="T_9c998_level0_col5" class="col_heading level0 col5" >% Non-Hate → Jewish</th>
#       <th id="T_9c998_level0_col6" class="col_heading level0 col6" >% Hate → Atheist</th>
#       <th id="T_9c998_level0_col7" class="col_heading level0 col7" >% Non-Hate → Atheist</th>
#       <th id="T_9c998_level0_col8" class="col_heading level0 col8" >% Hate → Buddhist</th>
#       <th id="T_9c998_level0_col9" class="col_heading level0 col9" >% Non-Hate → Buddhist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9
>100.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
def make_count_table(data):
    counts = (
        data.groupby(["annotator_group", "target_group"])
            .size()
            .unstack(fill_value=0)
            .reindex(index=annotator_religions, columns=target_religions, fill_value=0)
    )
    counts.index = [x.capitalize() + " annotators" for x in counts.index]
    counts.columns = [x.capitalize() for x in counts.columns]
    return counts

print("FULL COUNTS ")
display(make_count_table(df5))

print("TRAIN COUNTS ")
display(make_count_table(train_df))

print("TEST COUNTS ")
display(make_count_table(test_df))

print("VAL COUNTS ")
display(make_count_table(val_df))
# Out:
# FULL COUNTS
#                       Muslim  Christian  Jewish  Atheist  Buddhist
# Muslim annotators        106         39      37        5         0
# Christian annotators    5241       2402    2200      183        24
# Jewish annotators        202         78     120        6         1
# Atheist annotators      2580       1031    1161       81        11
# Buddhist annotators      180         98      66        3         1
# TRAIN COUNTS
#                       Muslim  Christian  Jewish  Atheist  Buddhist
# Muslim annotators         74         31       8        3         0
# Christian annotators    3377       1798     779      124        17
# Jewish annotators        124         53      52        3         1
# Atheist annotators      1653        773     442       55         7
# Buddhist annotators      111         74      21        1         0
# TEST COUNTS
#                       Muslim  Christian  Jewish  Atheist  Buddhist
# Muslim annotators         22          7      13        2         0
# Christian annotators    1215        384     702       41         4
# Jewish annotators         52         15      36        1         0
# Atheist annotators       630        175     374       18         1
# Buddhist annotators       46         15      28        1         0
# VAL COUNTS
#                       Muslim  Christian  Jewish  Atheist  Buddhist
# Muslim annotators         10          1      16        0         0
# Christian annotators     649        220     719       18         3
# Jewish annotators         26         10      32        2         0
# Atheist annotators       297         83     345        8         3
# Buddhist annotators       23          9      17        1         1

# %%
# # def mask_small_cells(percent_table, count_table, min_rows=30):
#     masked = percent_table.copy()
#     masked[count_table < min_rows] = np.nan
#     return masked

# %%
# full_table_masked  = mask_small_cells(full_table, make_count_table(df5), MIN_CELL_ROWS)
# train_table_masked = mask_small_cells(train_table, make_count_table(train_df), MIN_CELL_ROWS)
# test_table_masked  = mask_small_cells(test_table, make_count_table(test_df), MIN_CELL_ROWS)
# val_table_masked   = mask_small_cells(val_table, make_count_table(val_df), MIN_CELL_ROWS)

# display(full_table_masked.style.format("{:.2f}").set_caption("Full (masked small cells)"))
# display(train_table_masked.style.format("{:.2f}").set_caption("Train (masked small cells)"))
# display(test_table_masked.style.format("{:.2f}").set_caption("Test (masked small cells)"))
# display(val_table_masked.style.format("{:.2f}").set_caption("Val (masked small cells)"))

# %%
total_rows = len(df5)

train_pct = len(train_df) / total_rows * 100
test_pct  = len(test_df) / total_rows * 100
val_pct   = len(val_df) / total_rows * 100

print("ROW DISTRIBUTION ")
print(f"Train: {len(train_df)} rows ({train_pct:.2f}%)")
print(f"Test : {len(test_df)} rows ({test_pct:.2f}%)")
print(f"Val  : {len(val_df)} rows ({val_pct:.2f}%)")
print(f"Total after split: {len(train_df)+len(test_df)+len(val_df)}")
print(f"Original rows: {total_rows}")
# Out:
# ROW DISTRIBUTION
# Train: 9581 rows (60.43%)
# Test : 3782 rows (23.85%)
# Val  : 2493 rows (15.72%)
# Total after split: 15856
# Original rows: 15856

# %% [markdown]
# ### Count version of table -

# %%
def make_count_hate_nonhate_table(data):
    table = pd.DataFrame()

    for a in annotator_religions:
        row = {}
        sub_a = data[data["annotator_group"] == a]

        for t in target_religions:
            sub = sub_a[sub_a["target_group"] == t]

            hate_n = int(sub["is_hate_speech"].sum())
            total = len(sub)
            non_n = total - hate_n

            row[f"Hate (n) → {t.capitalize()}"] = hate_n
            row[f"Non-Hate (n) → {t.capitalize()}"] = non_n

        table = pd.concat([table, pd.DataFrame(row, index=[a.capitalize()+" annotators"])])

    return table

# %%
full_count_table  = make_count_hate_nonhate_table(df5)
train_count_table = make_count_hate_nonhate_table(train_df)
test_count_table  = make_count_hate_nonhate_table(test_df)
val_count_table   = make_count_hate_nonhate_table(val_df)

# %%
from IPython.display import display

def style_count_table(df, title):
    return (
        df.style
        .format("{:,.0f}")
        .set_caption(title)
        .set_table_styles([
            {"selector": "caption", "props": [("font-size", "16px"), ("font-weight", "bold")]},
            {"selector": "th", "props": [("background-color", "#f2f2f2"), ("font-weight", "bold")]}
        ])
        .background_gradient(cmap="Blues", axis=None)
    )

# %%
display(style_count_table(full_count_table,  "Full Dataset: Hate / Non-Hate (Counts)"))
display(style_count_table(train_count_table, "Train (70%) - Counts"))
display(style_count_table(test_count_table,  "Test (20%) - Counts"))
display(style_count_table(val_count_table,   "Validation (10%) - Counts"))
# Out:
# <style type="text/css">
# #T_4933e caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_4933e th {
#   background-color: #f2f2f2;
#   font-weight: bold;
# }
# #T_4933e_row0_col0, #T_4933e_row0_col3, #T_4933e_row0_col4, #T_4933e_row1_col6, #T_4933e_row2_col5 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_4933e_row0_col1, #T_4933e_row2_col3, #T_4933e_row3_col7, #T_4933e_row4_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_4933e_row0_col2, #T_4933e_row0_col5, #T_4933e_row0_col6, #T_4933e_row0_col7, #T_4933e_row0_col8, #T_4933e_row0_col9, #T_4933e_row1_col8, #T_4933e_row2_col2, #T_4933e_row2_col6, #T_4933e_row2_col7, #T_4933e_row2_col8, #T_4933e_row2_col9, #T_4933e_row3_col8, #T_4933e_row3_col9, #T_4933e_row4_col2, #T_4933e_row4_col6, #T_4933e_row4_col7, #T_4933e_row4_col8, #T_4933e_row4_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4933e_row1_col0 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_4933e_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4933e_row1_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_4933e_row1_col3 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_4933e_row1_col4 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_4933e_row1_col5 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_4933e_row1_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_4933e_row1_col9, #T_4933e_row3_col6, #T_4933e_row4_col5 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_4933e_row2_col0, #T_4933e_row2_col4, #T_4933e_row4_col3 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_4933e_row2_col1, #T_4933e_row3_col2, #T_4933e_row4_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_4933e_row3_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_4933e_row3_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_4933e_row3_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_4933e_row3_col4 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_4933e_row3_col5 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_4933e_row4_col4 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_4933e">
#   <caption>Full Dataset: Hate / Non-Hate (Counts)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4933e_level0_col0" class="col_heading level0 col0" >Hate (n) → Muslim</th>
#       <th id="T_4933e_level0_col1" class="col_heading level0 col1" >Non-Hate (n) → Muslim</th>
#       <th id="T_4933e_level0_col2" class="col_heading level0 col2" >Hate (n) → Christian</th>
#       <th id="T_4933e_level0_col3" class="col_heading level0 col3" >Non-Hate (n) → Christian</th>
#       <th id="T_4933e_level0_col4" class="col_heading level0 col4" >Hate (n) → Jewish</th>
#       <th id="T_4933e_level0_col5" class="col_heading level0 col5" >Non-Hate (n) → Jewish</th>
#       <th id="T_4933e_level0_col6" class="col_heading level0 col6" >Hate (n) → Atheist</th>
#       <th id="T_4933e_level0_col7" class="col_heading level0 col7" >Non-Hate (n) → Atheist</th>
#       <th id="T_4933e_level0_col8" class="col_heading level0 col8" >Hate (n) → Buddhist</th>
#       <th id="T_4933e_level0_col9" class="col_heading level0 col9" >Non-Hate (n) → Buddhist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4933e_level0_row0" class="row_heading level0 row0" >Muslim annotators</th>
#       <td id="T_4933e_row0_col0" class="data row0 col0" >35</td>
#       <td id="T_4933e_row0_col1" class="data row0 col1" >71</td>
#       <td id="T_4933e_row0_col2" class="data row0 col2" >5</td>
#       <td id="T_4933e_row0_col3" class="data row0 col3" >34</td>
#       <td id="T_4933e_row0_col4" class="data row0 col4" >28</td>
#       <td id="T_4933e_row0_col5" class="data row0 col5" >9</td>
#       <td id="T_4933e_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_4933e_row0_col7" class="data row0 col7" >4</td>
#       <td id="T_4933e_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_4933e_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4933e_level0_row1" class="row_heading level0 row1" >Christian annotators</th>
#       <td id="T_4933e_row1_col0" class="data row1 col0" >2,138</td>
#       <td id="T_4933e_row1_col1" class="data row1 col1" >3,103</td>
#       <td id="T_4933e_row1_col2" class="data row1 col2" >332</td>
#       <td id="T_4933e_row1_col3" class="data row1 col3" >2,070</td>
#       <td id="T_4933e_row1_col4" class="data row1 col4" >1,594</td>
#       <td id="T_4933e_row1_col5" class="data row1 col5" >606</td>
#       <td id="T_4933e_row1_col6" class="data row1 col6" >36</td>
#       <td id="T_4933e_row1_col7" class="data row1 col7" >147</td>
#       <td id="T_4933e_row1_col8" class="data row1 col8" >5</td>
#       <td id="T_4933e_row1_col9" class="data row1 col9" >19</td>
#     </tr>
#     <tr>
#       <th id="T_4933e_level0_row2" class="row_heading level0 row2" >Jewish annotators</th>
#       <td id="T_4933e_row2_col0" class="data row2 col0" >89</td>
#       <td id="T_4933e_row2_col1" class="data row2 col1" >113</td>
#       <td id="T_4933e_row2_col2" class="data row2 col2" >10</td>
#       <td id="T_4933e_row2_col3" class="data row2 col3" >68</td>
#       <td id="T_4933e_row2_col4" class="data row2 col4" >89</td>
#       <td id="T_4933e_row2_col5" class="data row2 col5" >31</td>
#       <td id="T_4933e_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_4933e_row2_col7" class="data row2 col7" >5</td>
#       <td id="T_4933e_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_4933e_row2_col9" class="data row2 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4933e_level0_row3" class="row_heading level0 row3" >Atheist annotators</th>
#       <td id="T_4933e_row3_col0" class="data row3 col0" >1,115</td>
#       <td id="T_4933e_row3_col1" class="data row3 col1" >1,465</td>
#       <td id="T_4933e_row3_col2" class="data row3 col2" >113</td>
#       <td id="T_4933e_row3_col3" class="data row3 col3" >918</td>
#       <td id="T_4933e_row3_col4" class="data row3 col4" >853</td>
#       <td id="T_4933e_row3_col5" class="data row3 col5" >308</td>
#       <td id="T_4933e_row3_col6" class="data row3 col6" >16</td>
#       <td id="T_4933e_row3_col7" class="data row3 col7" >65</td>
#       <td id="T_4933e_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_4933e_row3_col9" class="data row3 col9" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4933e_level0_row4" class="row_heading level0 row4" >Buddhist annotators</th>
#       <td id="T_4933e_row4_col0" class="data row4 col0" >69</td>
#       <td id="T_4933e_row4_col1" class="data row4 col1" >111</td>
#       <td id="T_4933e_row4_col2" class="data row4 col2" >11</td>
#       <td id="T_4933e_row4_col3" class="data row4 col3" >87</td>
#       <td id="T_4933e_row4_col4" class="data row4 col4" >46</td>
#       <td id="T_4933e_row4_col5" class="data row4 col5" >20</td>
#       <td id="T_4933e_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_4933e_row4_col7" class="data row4 col7" >3</td>
#       <td id="T_4933e_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_4933e_row4_col9" class="data row4 col9" >0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7376a caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_7376a th {
#   background-color: #f2f2f2;
#   font-weight: bold;
# }
# #T_7376a_row0_col0, #T_7376a_row0_col3, #T_7376a_row1_col6 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_7376a_row0_col1, #T_7376a_row2_col3, #T_7376a_row4_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_7376a_row0_col2, #T_7376a_row0_col4, #T_7376a_row0_col5, #T_7376a_row0_col6, #T_7376a_row0_col7, #T_7376a_row0_col8, #T_7376a_row0_col9, #T_7376a_row1_col8, #T_7376a_row2_col2, #T_7376a_row2_col6, #T_7376a_row2_col7, #T_7376a_row2_col8, #T_7376a_row2_col9, #T_7376a_row3_col8, #T_7376a_row3_col9, #T_7376a_row4_col6, #T_7376a_row4_col7, #T_7376a_row4_col8, #T_7376a_row4_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7376a_row1_col0 {
#   background-color: #1663aa;
#   color: #f1f1f1;
# }
# #T_7376a_row1_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7376a_row1_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_7376a_row1_col3 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_7376a_row1_col4 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_7376a_row1_col5 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_7376a_row1_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_7376a_row1_col9, #T_7376a_row3_col6, #T_7376a_row4_col2, #T_7376a_row4_col4, #T_7376a_row4_col5 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7376a_row2_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_7376a_row2_col1, #T_7376a_row4_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_7376a_row2_col4 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_7376a_row2_col5 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_7376a_row3_col0 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_7376a_row3_col1 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_7376a_row3_col2 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_7376a_row3_col3 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_7376a_row3_col4 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_7376a_row3_col5 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_7376a_row3_col7 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_7376a_row4_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# </style>
# <table id="T_7376a">
#   <caption>Train (70%) - Counts</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7376a_level0_col0" class="col_heading level0 col0" >Hate (n) → Muslim</th>
#       <th id="T_7376a_level0_col1" class="col_heading level0 col1" >Non-Hate (n) → Muslim</th>
#       <th id="T_7376a_level0_col2" class="col_heading level0 col2" >Hate (n) → Christian</th>
#       <th id="T_7376a_level0_col3" class="col_heading level0 col3" >Non-Hate (n) → Christian</th>
#       <th id="T_7376a_level0_col4" class="col_heading level0 col4" >Hate (n) → Jewish</th>
#       <th id="T_7376a_level0_col5" class="col_heading level0 col5" >Non-Hate (n) → Jewish</th>
#       <th id="T_7376a_level0_col6" class="col_heading level0 col6" >Hate (n) → Atheist</th>
#       <th id="T_7376a_level0_col7" class="col_heading level0 col7" >Non-Hate (n) → Atheist</th>
#       <th id="T_7376a_level0_col8" class="col_heading level0 col8" >Hate (n) → Buddhist</th>
#       <th id="T_7376a_level0_col9" class="col_heading level0 col9" >Non-Hate (n) → Buddhist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7376a_level0_row0" class="row_heading level0 row0" >Muslim annotators</th>
#       <td id="T_7376a_row0_col0" class="data row0 col0" >28</td>
#       <td id="T_7376a_row0_col1" class="data row0 col1" >46</td>
#       <td id="T_7376a_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_7376a_row0_col3" class="data row0 col3" >28</td>
#       <td id="T_7376a_row0_col4" class="data row0 col4" >3</td>
#       <td id="T
{
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_17d54_row4_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# </style>
# <table id="T_17d54">
#   <caption>Validation (10%) - Counts</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17d54_level0_col0" class="col_heading level0 col0" >Hate (n) → Muslim</th>
#       <th id="T_17d54_level0_col1" class="col_heading level0 col1" >Non-Hate (n) → Muslim</th>
#       <th id="T_17d54_level0_col2" class="col_heading level0 col2" >Hate (n) → Christian</th>
#       <th id="T_17d54_level0_col3" class="col_heading level0 col3" >Non-Hate (n) → Christian</th>
#       <th id="T_17d54_level0_col4" class="col_heading level0 col4" >Hate (n) → Jewish</th>
#       <th id="T_17d54_level0_col5" class="col_heading level0 col5" >Non-Hate (n) → Jewish</th>
#       <th id="T_17d54_level0_col6" class="col_heading level0 col6" >Hate (n) → Atheist</th>
#       <th id="T_17d54_level0_col7" class="col_heading level0 col7" >Non-Hate (n) → Atheist</th>
#       <th id="T_17d54_level0_col8" class="col_heading level0 col8" >Hate (n) → Buddhist</th>
#       <th id="T_17d54_level0_col9" class="col_heading level0 col9" >Non-Hate (n) → Buddhist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17d54_level0_row0" class="row_heading level0 row0" >Muslim annotators</th>
#       <td id="T_17d54_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_17d54_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_17d54_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_17d54_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_17d54_row0_col4" class="data row0 col4" >15</td>
#       <td id="T_17d54_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_17d54_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_17d54_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_17d54_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_17d54_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_17d54_level0_row1" class="row_heading level0 row1" >Christian annotators</th>
#       <td id="T_17d54_row1_col0" class="data row1 col0" >68</td>
#       <td id="T_17d54_row1_col1" class="data row1 col1" >581</td>
#       <td id="T_17d54_row1_col2" class="data row1 col2" >30</td>
#       <td id="T_17d54_row1_col3" class="data row1 col3" >190</td>
#       <td id="T_17d54_row1_col4" class="data row1 col4" >647</td>
#       <td id="T_17d54_row1_col5" class="data row1 col5" >72</td>
#       <td id="T_17d54_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_17d54_row1_col7" class="data row1 col7" >16</td>
#       <td id="T_17d54_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_17d54_row1_col9" class="data row1 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_17d54_level0_row2" class="row_heading level0 row2" >Jewish annotators</th>
#       <td id="T_17d54_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_17d54_row2_col1" class="data row2 col1" >25</td>
#       <td id="T_17d54_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_17d54_row2_col3" class="data row2 col3" >7</td>
#       <td id="T_17d54_row2_col4" class="data row2 col4" >30</td>
#       <td id="T_17d54_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_17d54_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_17d54_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_17d54_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_17d54_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_17d54_level0_row3" class="row_heading level0 row3" >Atheist annotators</th>
#       <td id="T_17d54_row3_col0" class="data row3 col0" >36</td>
#       <td id="T_17d54_row3_col1" class="data row3 col1" >261</td>
#       <td id="T_17d54_row3_col2" class="data row3 col2" >11</td>
#       <td id="T_17d54_row3_col3" class="data row3 col3" >72</td>
#       <td id="T_17d54_row3_col4" class="data row3 col4" >310</td>
#       <td id="T_17d54_row3_col5" class="data row3 col5" >35</td>
#       <td id="T_17d54_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_17d54_row3_col7" class="data row3 col7" >7</td>
#       <td id="T_17d54_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_17d54_row3_col9" class="data row3 col9" >3</td>
#     </tr>
#     <tr>
#       <th id="T_17d54_level0_row4" class="row_heading level0 row4" >Buddhist annotators</th>
#       <td id="T_17d54_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_17d54_row4_col1" class="data row4 col1" >21</td>
#       <td id="T_17d54_row4_col2" class="data row4 col2" >2</td>
#       <td id="T_17d54_row4_col3" class="data row4 col3" >7</td>
#       <td id="T_17d54_row4_col4" class="data row4 col4" >15</td>
#       <td id="T_17d54_row4_col5" class="data row4 col5" >2</td>
#       <td id="T_17d54_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_17d54_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_17d54_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_17d54_row4_col9" class="data row4 col9" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### COUNT AND PERCENTAGE TOGETHER VERSION OF TABLE

# %%
def make_combined_table(data):
    table = pd.DataFrame()

    for a in annotator_religions:
        row = {}
        sub_a = data[data["annotator_group"] == a]

        for t in target_religions:
            sub = sub_a[sub_a["target_group"] == t]
            total = len(sub)

            hate_n = int(sub["is_hate_speech"].sum())
            non_n = total - hate_n

            if total > 0:
                hate_pct = hate_n / total * 100
                non_pct = non_n / total * 100

                hate_text = f"{hate_pct:.2f}% ({hate_n}/{total})"
                non_text  = f"{non_pct:.2f}% ({non_n}/{total})"
            else:
                hate_text = "—"
                non_text  = "—"

            row[f"% Hate - {t.capitalize()}"] = hate_text
            row[f"% Non-Hate - {t.capitalize()}"] = non_text

        table = pd.concat([table, pd.DataFrame(row, index=[a.capitalize() + " annotators"])])

    return table

# %%
full_combined  = make_combined_table(df5)
train_combined = make_combined_table(train_df)
test_combined  = make_combined_table(test_df)
val_combined   = make_combined_table(val_df)

# %%
from IPython.display import display

def style_combined(df, title):
    return (
        df.style
        .set_caption(title)
        .set_table_styles([
            {"selector": "caption", "props": [("font-size", "16px"), ("font-weight", "bold")]},
            {"selector": "th", "props": [("background-color", "#f2f2f2"), ("font-weight", "bold")]},
            {"selector": "td", "props": [("font-family", "Arial"), ("font-size", "12px")]}
        ])
    )

display(style_combined(full_combined,  "Full Dataset: Hate vs Non-Hate (%, counts)"))
display(style_combined(train_combined, "Train (70%): Hate vs Non-Hate (%, counts)"))
display(style_combined(test_combined,  "Test (20%): Hate vs Non-Hate (%, counts)"))
display(style_combined(val_combined,   "Validation (10%): Hate vs Non-Hate (%, counts)"))
# Out:
# <style type="text/css">
# #T_4b004 caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_4b004 th {
#   background-color: #f2f2f2;
#   font-weight: bold;
# }
# #T_4b004 td {
#   font-family: Arial;
#   font-size: 12px;
# }
# </style>
# <table id="T_4b004">
#   <caption>Full Dataset: Hate vs Non-Hate (%, counts)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b004_level0_col0" class="col_heading level0 col0" >% Hate - Muslim</th>
#       <th id="T_4b004_level0_col1" class="col_heading level0 col1" >% Non-Hate - Muslim</th>
#       <th id="T_4b004_level0_col2" class="col_heading level0 col2" >% Hate - Christian</th>
#       <th id="T_4b004_level0_col3" class="col_heading level0 col3" >% Non-Hate - Christian</th>
#       <th id="T_4b004_level0_col4" class="col_heading level0 col4" >% Hate - Jewish</th>
#       <th id="T_4b004_level0_col5" class="col_heading level0 col5" >% Non-Hate - Jewish</th>
#       <th id="T_4b004_level0_col6" class="col_heading level0 col6" >% Hate - Atheist</th>
#       <th id="T_4b004_level0_col7" class="col_heading level0 col7" >% Non-Hate - Atheist</th>
#       <th id="T_4b004_level0_col8" class="col_heading level0 col8" >% Hate - Buddhist</th>
#       <th id="T_4b004_level0_col9" class="col_heading level0 col9" >% Non-Hate - Buddhist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4
#       <td id="T_4b004_row3_col4" class="data row3 col4" >73.47% (853/1161)</td>
#       <td id="T_4b004_row3_col5" class="data row3 col5" >26.53% (308/1161)</td>
#       <td id="T_4b004_row3_col6" class="data row3 col6" >19.75% (16/81)</td>
#       <td id="T_4b004_row3_col7" class="data row3 col7" >80.25% (65/81)</td>
#       <td id="T_4b004_row3_col8" class="data row3 col8" >9.09% (1/11)</td>
#       <td id="T_4b004_row3_col9" class="data row3 col9" >90.91% (10/11)</td>
#     </tr>
#     <tr>
#       <th id="T_4b004_level0_row4" class="row_heading level0 row4" >Buddhist annotators</th>
#       <td id="T_4b004_row4_col0" class="data row4 col0" >38.33% (69/180)</td>
#       <td id="T_4b004_row4_col1" class="data row4 col1" >61.67% (111/180)</td>
#       <td id="T_4b004_row4_col2" class="data row4 col2" >11.22% (11/98)</td>
#       <td id="T_4b004_row4_col3" class="data row4 col3" >88.78% (87/98)</td>
#       <td id="T_4b004_row4_col4" class="data row4 col4" >69.70% (46/66)</td>
#       <td id="T_4b004_row4_col5" class="data row4 col5" >30.30% (20/66)</td>
#       <td id="T_4b004_row4_col6" class="data row4 col6" >0.00% (0/3)</td>
#       <td id="T_4b004_row4_col7" class="data row4 col7" >100.00% (3/3)</td>
#       <td id="T_4b004_row4_col8" class="data row4 col8" >100.00% (1/1)</td>
#       <td id="T_4b004_row4_col9" class="data row4 col9" >0.00% (0/1)</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3689a caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_3689a th {
#   background-color: #f2f2f2;
#   font-weight: bold;
# }
# #T_3689a td {
#   font-family: Arial;
#   font-size: 12px;
# }
# </style>
# <table id="T_3689a">
#   <caption>Train (70%): Hate vs Non-Hate (%, counts)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3689a_level0_col0" class="col_heading level0 col0" >% Hate - Muslim</th>
#       <th id="T_3689a_level0_col1" class="col_heading level0 col1" >% Non-Hate - Muslim</th>
#       <th id="T_3689a_level0_col2" class="col_heading level0 col2" >% Hate - Christian</th>
#       <th id="T_3689a_level0_col3" class="col_heading level0 col3" >% Non-Hate - Christian</th>
#       <th id="T_3689a_level0_col4" class="col_heading level0 col4" >% Hate - Jewish</th>
#       <th id="T_3689a_level0_col5" class="col_heading level0 col5" >% Non-Hate - Jewish</th>
#       <th id="T_3689a_level0_col6" class="col_heading level0 col6" >% Hate - Atheist</th>
#       <th id="T_3689a_level0_col7" class="col_heading level0 col7" >% Non-Hate - Atheist</th>
#       <th id="T_3689a_level0_col8" class="col_heading level0 col8" >% Hate - Buddhist</th>
#       <th id="T_3689a_level0_col9" class="col_heading level0 col9" >% Non-Hate - Buddhist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3689a_level0_row0" class="row_heading level0 row0" >Muslim annotators</th>
#       <td id="T_3689a_row0_col0" class="data row0 col0" >37.84% (28/74)</td>
#       <td id="T_3689a_row0_col1" class="data row0 col1" >62.16% (46/74)</td>
#       <td id="T_3689a_row0_col2" class="data row0 col2" >9.68% (3/31)</td>
#       <td id="T_3689a_row0_col3" class="data row0 col3" >90.32% (28/31)</td>
#       <td id="T_3689a_row0_col4" class="data row0 col4" >37.50% (3/8)</td>
#       <td id="T_3689a_row0_col5" class="data row0 col5" >62.50% (5/8)</td>
#       <td id="T_3689a_row0_col6" class="data row0 col6" >33.33% (1/3)</td>
#       <td id="T_3689a_row0_col7" class="data row0 col7" >66.67% (2/3)</td>
#       <td id="T_3689a_row0_col8" class="data row0 col8" >—</td>
#       <td id="T
#       <td id="T_3689a_row3_col9" class="data row3 col9" >85.71% (6/7)</td>
#     </tr>
#     <tr>
#       <th id="T_3689a_level0_row4" class="row_heading level0 row4" >Buddhist annotators</th>
#       <td id="T_3689a_row4_col0" class="data row4 col0" >41.44% (46/111)</td>
#       <td id="T_3689a_row4_col1" class="data row4 col1" >58.56% (65/111)</td>
#       <td id="T_3689a_row4_col2" class="data row4 col2" >10.81% (8/74)</td>
#       <td id="T_3689a_row4_col3" class="data row4 col3" >89.19% (66/74)</td>
#       <td id="T_3689a_row4_col4" class="data row4 col4" >42.86% (9/21)</td>
#       <td id="T_3689a_row4_col5" class="data row4 col5" >57.14% (12/21)</td>
#       <td id="T_3689a_row4_col6" class="data row4 col6" >0.00% (0/1)</td>
#       <td id="T_3689a_row4_col7" class="data row4 col7" >100.00% (1/1)</td>
#       <td id="T_3689a_row4_col8" class="data row4 col8" >—</td>
#       <td id="T_3689a_row4_col9" class="data row4 col9" >—</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bd81e caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_bd81e th {
#   background-color: #f2f2f2;
#   font-weight: bold;
# }
# #T_bd81e td {
#   font-family: Arial;
#   font-size: 12px;
# }
# </style>
# <table id="T_bd81e">
#   <caption>Test (20%): Hate vs Non-Hate (%, counts)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd81e_level0_col0" class="col_heading level0 col0" >% Hate - Muslim</th>
#       <th id="T_bd81e_level0_col1" class="col_heading level0 col1" >% Non-Hate - Muslim</th>
#       <th id="T_bd81e_level0_col2" class="col_heading level0 col2" >% Hate - Christian</th>
#       <th id="T_bd81e_level0_col3" class="col_heading level0 col3" >% Non-Hate - Christian</th>
#       <th id="T_bd81e_level0_col4" class="col_heading level0 col4" >% Hate - Jewish</th>
#       <th id="T_bd81e_level0_col5" class="col_heading level0 col5" >% Non-Hate - Jewish</th>
#       <th id="T_bd81e_level0_col6" class="col_heading level0 col6" >% Hate - Atheist</th>
#       <th id="T_bd81e_level0_col7" class="col_heading level0 col7" >% Non-Hate - Atheist</th>
#       <th id="T_bd81e_level0_col8" class="col_heading level0 col8" >% Hate - Buddhist</th>
#       <th id="T_bd81e_level0_col9" class="col_heading level0 col9" >% Non-Hate - Buddhist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd81e_level0_row0" class="row_heading level0 row0" >Muslim annotators</th>
#       <td id="T_bd81e_row0_col0" class="data row0 col0" >31.82% (7/22)</td>
#       <td id="T_bd81e_row0_col1" class="data row0 col1" >68.18% (15/22)</td>
#       <td id="T_bd81e_row0_col2" class="data row0 col2" >28.57% (2/7)</td>
#       <td id="T_bd81e_row0_col3" class="data row0 col3" >71.43% (5/7)</td>
#       <td id="T_bd81e_row0_col4" class="data row0 col4" >76.92% (10/13)</td>
#       <td id="T_bd81e_row0_col5" class="data row0 col5" >23.08% (3/13)</td>
#       <td id="T_bd81e_row0_col6" class="data row0 col6" >0.00% (0/2)</td>
#       <td id="T_bd81e_row0_col7" class="data row0 col7" >100.00% (2/2)</td>
#       <td id="T_bd81e_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_bd81e_row0_col9" class="data row0 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_bd81e_level0_row1" class="row_heading level0 row1" >Christian annotators</th>
#       <td id="T_bd81e_row1_col0" class="data row1 col0" >46.75% (568/1215)</td>
#       <td id="T_bd81e_row1_col1" class="data row1 col1" >53.25% (647/1215)</td>
#       <td id="T_bd81e_row1_col2" class="data row1 col2" >20.83% (80/384)</td>
#       <td id="T_bd81e_row1_col3" class="data row1 col3" >79.17% (304/384)</td>
#       <td id="T_bd81e_row1_col4" class="data row1 col4" >81.91% (575/702)</td>
#       <td id="T_bd81e_row1_col5" class="data row1 col5" >18.09% (127/702)</td>
#       <td id="T_bd81e_row1_col6" class="data row1 col6" >26.83% (11/41)</td>
#       <td id="T_bd81e_row1_col7" class="data row1 col7" >73.17% (30/41)</td>
#       <td id="T_bd81e_row1_col8" class="data row1 col8" >25.00% (1/4)</td>
#       <td id="T_bd81e_row1_col9" class="data row1 col9" >75.00% (3/4)</td>
#     </tr>
#     <tr>
#       <th id="T_bd81e_level0_row2" class="row_heading level0 row2" >Jewish annotators</th>
#       <td id="T_bd81e_row2_col0" class="data row2 col0" >57.69% (30/52)</td>
#       <td id="T_bd81e_row2_col1" class="data row2 col1" >42.31% (22/52)</td>
#       <td id="T_bd81e_row2_col2" class="data row2 col2" >20.00% (3/15)</td>
#       <td id="T_bd81e_row2_col3" class="data row2 col3" >80.00% (12/15)</td>
#       <td id="T_bd81e_row2_col4" class="data row2 col4" >77.78% (28/36)</td>
#       <td id="T_bd81e_row2_col5" class="data row2 col5" >22.22% (8/36)</td>
#       <td id="T_bd81e_row2_col6" class="data row2 col6" >0.00% (0/1)</td>
#       <td id="T_bd81e_row2_col7" class="data row2 col7" >100.00% (1/1)</td>
#       <td id="T_bd81e_row2_col8" class="data row2 col8" >—</td>
#       <td id="T_bd81e_row2_col9" class="data row2 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_bd81e_level0_row3" class="row_heading level0 row3" >Atheist annotators</th>
#       <td id="T_bd81e_row3_col0" class="data row3 col0" >49.68% (313/630)</td>
#       <td id="T_bd81e_row3_col1" class="data row3 col1" >50.32% (317/630)</td>
#       <td id="T_bd81e_row3_col2" class="data row3 col2" >16.00% (28/175)</td>
#       <td id="T_bd81e_row3_col3" class="data row3 col3" >84.00% (147/175)</td>
#       <td id="T_bd81e_row3_col4" class="data row3 col4" >83.96% (314/374)</td>
#       <td id="T_bd81e_row3_col5" class="data row3 col5" >16.04% (60/374)</td>
#       <td id="T_bd81e_row3_col6" class="data row3 col6" >16.67% (3/18)</td>
#       <td id="T_bd81e_row3_col7" class="data row3 col7" >83.33% (15/18)</td>
#       <td id="T_bd81e_row3_col8" class="data row3 col8" >0.00% (0/1)</td>
#       <td id="T_bd81e_row3_col9" class="data row3 col9" >100.00% (1/1)</td>
#     </tr>
#     <tr>
#       <th id="T_bd81e_level0_row4" class="row_heading level0 row4" >Buddhist annotators</th>
#       <td id="T_bd81e_row4_col0" class="data row4 col0" >45.65% (21/46)</td>
#       <td id="T_bd81e_row4_col1" class="data row4 col1" >54.35% (25/46)</td>
#       <td id="T_bd81e_row4_col2" class="data row4 col2" >6.67% (1/15)</td>
#       <td id="T_bd81e_row4_col3" class="data row4 col3" >93.33% (14/15)</td>
#       <td id="T_bd81e_row4_col4" class="data row4 col4" >78.57% (22/28)</td>
#       <td id="T_bd81e_row4_col5" class="data row4 col5" >21.43% (6/28)</td>
#       <td id="T_bd81e_row4_col6" class="data row4 col6" >0.00% (0/1)</td>
#       <td id="T_bd81e_row4_col7" class="data row4 col7" >100.00% (1/1)</td>
#       <td id="T_bd81e_row4_col8" class="data row4 col8" >—</td>
#       <td id="T_bd81e_row4_col9" class="data row4 col9" >—</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ed016 caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# #T_ed016 th {
#   background-color: #f2f2f2;
#   font-weight: bold;
# }
# #T_ed016 td {
#   font-family: Arial;
#   font-size: 12px;
# }
# </style>
# <table id="T_ed016">
#   <caption>Validation (10%): Hate vs Non-Hate (%, counts)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed016_level0_col0" class="col_heading level0 col0" >% Hate - Muslim</th>
#       <th id="T_ed016_level0_col1" class="col_heading level0 col1" >% Non-Hate - Muslim</th>
#       <th id="T_ed016_level0_col2" class="col_heading level0 col2" >% Hate - Christian</th>
#       <th id="T_ed016_level0_col3" class="col_heading level0 col3" >% Non-Hate - Christian</th>
#       <th id="T_ed016_level0_col4" class="col_heading level0 col4" >% Hate - Jewish</th>
#       <th id="T_ed016_level0_col5" class="col_heading level0 col5" >% Non-Hate - Jewish</th>
#       <th id="T_ed016_level0_col6" class="col_heading level0 col6" >% Hate - Atheist</th>
#       <th id="T_ed016_level0_col7" class="col_heading level0 col7" >% Non-Hate - Atheist</th>
#       <th id="T_ed016_level0_col8" class="col_heading level0 col8" >% Hate - Buddhist</th>
#       <th id="T_ed016_level0_col9" class="col_heading level0 col9" >% Non-Hate - Buddhist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed016_level0_row0" class="row_heading level0 row0" >Muslim annotators</th>
#       <td id="T_ed016_row0_col0" class="data row0 col0" >0.00% (0/10)</td>
#       <td id="T_ed016_row0_col1" class="data row0 col1" >100.00% (10/10)</td>
#       <td id="T_ed016_row0_col2" class="data row0 col2" >0.00% (0/1)</td>
#       <td id="T_ed016_row0_col3" class="data row0 col3" >100.00% (1/1)</td>
#       <td id="T_ed016_row0_col4" class="data row0 col4" >93.75% (15/16)</td>
#       <td id="T_ed016_row0_col5" class="data row0 col5" >6.25% (1/16)</td>
#       <td id="T_ed016_row0_col6" class="data row0 col6" >—</td>
#       <td id="T_ed016_row0_col7" class="data row0 col7" >—</td>
#       <td id="T_ed016_row0_col8" class="data row0 col8" >—</td>
#       <td id="T_ed016_row0_col9" class="data row0 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_ed016_level0_row1" class="row_heading level0 row1" >Christian annotators</th>
#       <td id="T_ed016_row1_col0" class="data row1 col0" >10.48% (68/649)</td>
#       <td id="T_ed016_row1_col1" class="data row1 col1" >89.52% (581/649)</td>
#       <td id="T_ed016_row1_col2" class="data row1 col2" >13.64% (30/220)</td>
#       <td id="T_ed016_row1_col3" class="data row1 col3" >86.36% (190/220)</td>
#       <td id="T_ed016_row1_col4" class="data row1 col4" >89.99% (647/719)</td>
#       <td id="T_ed016_row1_col5" class="data row1 col5" >10.01% (72/719)</td>
#       <td id="T_ed016_row1_col6" class="data row1 col6" >11.11% (2/18)</td>
#       <td id="T_ed016_row1_col7" class="data row1 col7" >88.89% (16/18)</td>
#       <td id="T_ed016_row1_col8" class="data row1 col8" >0.00% (0/3)</td>
#       <td id="T_ed016_row1_col9" class="data row1 col9" >100.00% (3/3)</td>
#     </tr>
#     <tr>
#       <th id="T_ed016_level0_row2" class="row_heading level0 row2" >Jewish annotators</th>
#       <td id="T_ed016_row2_col0" class="data row2 col0" >3.85% (1/26)</td>
#       <td id="T_ed016_row2_col1" class="data row2 col1" >96.15% (25/26)</td>
#       <td id="T_ed016_row2_col2" class="data row2 col2" >30.00% (3/10)</td>
#       <td id="T_ed016_row2_col3" class="data row2 col3" >70.00% (7/10)</td>
#       <td id="T_ed016_row2_col4" class="data row2 col4" >93.75% (30/32)</td>
#       <td id="T_ed016_row2_col5" class="data row2 col5" >6.25% (2/32)</td>
#       <td id="T_ed016_row2_col6" class="data row2 col6" >0.00% (0/2)</td>
#       <td id="T_ed016_row2_col7" class="data row2 col7" >100.00% (2/2)</td>
#       <td id="T_ed016_row2_col8" class="data row2 col8" >—</td>
#       <td id="T_ed016_row2_col9" class="data row2 col9" >—</td>
#     </tr>
#     <tr>
#       <th id="T_ed016_level0_row3" class="row_heading level0 row3" >Atheist annotators</th>
#       <td id="T_ed016_row3_col0" class="data row3 col0" >12.12% (36/297)</td>
#       <td id="T_ed016_row3_col1" class="data row3 col1" >87.88% (261/297)</td>
#       <td id="T_ed016_row3_col2" class="data row3 col2" >13.25% (11/83)</td>
#       <td id="T_ed016_row3_col3" class="data row3 col3" >86.75% (72/83)</td>
#       <td id="T_ed016_row3_col4" class="data row3 col4" >89.86% (310/345)</td>
#       <td id="T_ed016_row3_col5" class="data row3 col5" >10.14% (35/345)</td>
#       <td id="T_ed016_row3_col6" class="data row3 col6" >12.50% (1/8)</td>
#       <td id="T_ed016_row3_col7" class="data row3 col7" >87.50% (7/8)</td>
#       <td id="T_ed016_row3_col8" class="data row3 col8" >0.00% (0/3)</td>
#       <td id="T_ed016_row3_col9" class="data row3 col9" >100.00% (3/3)</td>
#     </tr>
#     <tr>
#       <th id="T_ed016_level0_row4" class="row_heading level0 row4" >Buddhist annotators</th>
#       <td id="T_ed016_row4_col0" class="data row4 col0" >8.70% (2/23)</td>
#       <td id="T_ed016_row4_col1" class="data row4 col1" >91.30% (21/23)</td>
#       <td id="T_ed016_row4_col2" class="data row4 col2" >22.22% (2/9)</td>
#       <td id="T_ed016_row4_col3" class="data row4 col3" >77.78% (7/9)</td>
#       <td id="T_ed016_row4_col4" class="data row4 col4" >88.24% (15/17)</td>
#       <td id="T_ed016_row4_col5" class="data row4 col5" >11.76% (2/17)</td>
#       <td id="T_ed016_row4_col6" class="data row4 col6" >0.00% (0/1)</td>
#       <td id="T_ed016_row4_col7" class="data row4 col7" >100.00% (1/1)</td>
#       <td id="T_ed016_row4_col8" class="data row4 col8" >100.00% (1/1)</td>
#       <td id="T_ed016_row4_col9" class="data row4 col9" >0.00% (0/1)</td>
#     </tr>
#   </tbody>
# </table>
